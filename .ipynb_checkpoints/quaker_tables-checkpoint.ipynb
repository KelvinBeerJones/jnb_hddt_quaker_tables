# %% [markdown]
# # HDDT Quakers (tables) #

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20, 10))
import numpy as np
import csv

# %%
quakers = pd.read_csv ('vw_1_quaker_all_202108191909.csv')
quaker_relationships = pd.read_csv ('vw_5_person1_person2_202107121948.csv')
quaker_distant = pd.read_csv ('vw_5_person_person_rel1_202108192002.csv')
quaker_close = pd.read_csv ('vw_5_person_person_rel2_202108192006.csv')
quaker_immediate = pd.read_csv ('vw_5_person_person_rel3_202108192007.csv')
quaker_ceda = pd.read_csv ('vw_4_ceda_membership_quakers_202107121945.csv')

# %%
quakers
# Out:
#     family_name     first_names  birth_year  death_year religion  confirmed  \
# 0          Wood  William Spicer         NaN      1902.0   Quaker          0
# 1        Wilson         William      1785.0      1868.0   Quaker          0
# 2        Wilson           James         NaN         NaN   Quaker          0
# 3     Wakefield             E T         NaN         NaN   Quaker          1
# 4          Ross            John         NaN         NaN   Quaker          0
# ..          ...             ...         ...         ...      ...        ...
# 588      Wilson          Joshua         NaN         NaN   Quaker          1
# 589    Woodhead               F         NaN         NaN   Quaker          1
# 590    Woolston               W         NaN         NaN   Quaker          1
# 591      Wright         Francis         NaN         NaN   Quaker          1
# 592      Wright             S W         NaN         NaN   Quaker          1
#
#                                                  notes
# 0                               Multiple possibilities
# 1                               Multiple possibilities
# 2                               Multiple possibilities
# 3    Edward T. Wakefield (1821-1896), of Portadown,...
# 4    Possibly John Ross (1798-1863), of Chatteris, ...
# ..                                                 ...
# 588  Joshua Wilson (1806-1877), merchant, ship and ...
# 589  Firth Woodhead (1811-1874), grocer and tea dea...
# 590    William Woolston (1817-1898), of Wellingborough
# 591  Francis Wright (1774-1850), tanner, chemist, a...
# 592  Samuel Williams Wright (1811-1895), farmer and...
#
# [593 rows x 7 columns]

# %%
quaker_relationships
# Out:
#                    Source            Target  relationship_type_id
# 0           William Aldam             x Fox                     1
# 1       William Jun Aldam             x Fox                     1
# 2     Frederick Alexander     R D Alexander                     1
# 3           G W Alexander     R D Alexander                     1
# 4         Henry Alexander     R D Alexander                     1
# ...                   ...               ...                   ...
# 2094    Alfred Waterhouse      R Waterhouse                     3
# 2095      Mary Waterhouse        Paul Bevan                     3
# 2096       Lucy Westcombe  Thomas Westcombe                     3
# 2097     Benjamin Wheeler    Samuel Wheeler                     3
# 2098       Charles Wilson     Joshua Wilson                     3
#
# [2099 rows x 3 columns]

# %%
quaker_immediate
# Out:
#                 Source            Target  relationship_type_id
# 0      Arthur Albright   John M Albright                     3
# 1      Arthur Albright   Rachel Albright                     3
# 2      Arthur Albright  William Albright                     3
# 3      Rachel Albright   John M Albright                     3
# 4      Rachel Albright  William Albright                     3
# ..                 ...               ...                   ...
# 244  Alfred Waterhouse      R Waterhouse                     3
# 245    Mary Waterhouse        Paul Bevan                     3
# 246     Lucy Westcombe  Thomas Westcombe                     3
# 247   Benjamin Wheeler    Samuel Wheeler                     3
# 248     Charles Wilson     Joshua Wilson                     3
#
# [249 rows x 3 columns]

# %%
quaker_close
# Out:
#                   Source              Target  relationship_type_id
# 0          R D Alexander  Christopher Bowley                     2
# 1          R D Alexander    Robert Charleton                     2
# 2          R D Alexander     Frederick H Fox                     2
# 3          R D Alexander          Thomas Maw                     2
# 4          R D Alexander      William Norton                     2
# ..                   ...                 ...                   ...
# 517            W Whiting        John Whiting                     2
# 518         Isaac Wilson       S Braithwaite                     2
# 519         Isaac Wilson         John Jowett                     2
# 520         Isaac Wilson       John E Wilson                     2
# 521  William Spicer Wood    Daniel Doncaster                     2
#
# [522 rows x 3 columns]

# %%
quaker_distant
# Out:
#                    Source               Target  relationship_type_id
# 0           William Aldam                x Fox                     1
# 1       William Jun Aldam                x Fox                     1
# 2     Frederick Alexander        R D Alexander                     1
# 3           G W Alexander        R D Alexander                     1
# 4         Henry Alexander        R D Alexander                     1
# ...                   ...                  ...                   ...
# 1323       William Wilson    Barnard Dickinson                     1
# 1324       William Wilson      Frederick Fryer                     1
# 1325       William Wilson  Benjamin Jowett (2)                     1
# 1326       William Wilson           John Pease                     1
# 1327       William Wilson         Joseph Pease                     1
#
# [1328 rows x 3 columns]

# %%
quaker_ceda
# Out:
#      person_id                 Name  religion_id religion_name  ceda_id  \
# 0         2233  William Spicer Wood            1        Quaker        2
# 1         2233  William Spicer Wood            1        Quaker        4
# 2         2233  William Spicer Wood            1        Quaker        6
# 3         2211       William Wilson            1        Quaker        2
# 4         2211       William Wilson            1        Quaker        4
# ..         ...                  ...          ...           ...      ...
# 639       2876        Joshua Wilson            1        Quaker        2
# 640       2877           F Woodhead            1        Quaker        2
# 641       2878           W Woolston            1        Quaker        2
# 642       2879       Francis Wright            1        Quaker        2
# 643       2880           S W Wright            1        Quaker        2
#
#     ceda_name  person_ceda_first_year  person_ceda_last_year
# 0         APS                    1864                   1867
# 1         ASL                    1863                   1871
# 2          AI                    1863                   1871
# 3         APS                    1838                   1865
# 4         ASL                    1865                   1866
# ..        ...                     ...                    ...
# 639       APS                    1860                   1860
# 640       APS                    1861                   1862
# 641       APS                    1861                   1861
# 642       APS                    1838                   1838
# 643       APS                    1861                   1861
#
# [644 rows x 8 columns]

# %%
quaker_ceda.groupby('person_ceda_first_year')['Name'].nunique().plot(kind='bar')
plt.title ("Number of joiners in each year")
plt.ylabel ("No. of joiners")
plt.show()

# %%
quaker_ceda.groupby('person_ceda_last_year')['Name'].nunique().plot(kind='bar')
plt.title ("Number of leavers in each year")
plt.ylabel ("No. of joiners")
plt.show()
